# %%
import pandas as pd
import numpy as np
csv_path = "./Advertising.csv"

# %%
data_df = pd.read_csv(csv_path, index_col=0)
data_df.head()
# Out:
#       TV  radio  newspaper  sales
# 1  230.1   37.8       69.2   22.1
# 2   44.5   39.3       45.1   10.4
# 3   17.2   45.9       69.3    9.3
# 4  151.5   41.3       58.5   18.5
# 5  180.8   10.8       58.4   12.9

# %%
X = data_df[["TV"]].to_numpy() 
Y = data_df[["sales"]].to_numpy()

# %%
# !pip install -U scikit-learn
# Out:
# Collecting scikit-learn
#   Downloading scikit_learn-1.7.2-cp310-cp310-win_amd64.whl (8.9 MB)
#      ---------------------------------------- 8.9/8.9 MB 1.1 MB/s eta 0:00:00
# Collecting joblib>=1.2.0
#   Downloading joblib-1.5.3-py3-none-any.whl (309 kB)
#      -------------------------------------- 309.1/309.1 kB 2.1 MB/s eta 0:00:00
# Requirement already satisfied: scipy>=1.8.0 in d:\data_science\dsml\.venv\lib\site-packages (from scikit-learn) (1.15.3)
# Requirement already satisfied: numpy>=1.22.0 in d:\data_science\dsml\.venv\lib\site-packages (from scikit-learn) (2.2.6)
# Collecting threadpoolctl>=3.1.0
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, joblib, scikit-learn
# Successfully installed joblib-1.5.3 scikit-learn-1.7.2 threadpoolctl-3.6.0
# [notice] A new release of pip available: 22.3.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(
    X, Y, 
)

# %%
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt

# %%
x = np.random.standard_t(500, size = 1000)
x[:15]
# Out:
# array([-0.20001921,  1.84576088, -0.61720116,  0.51164012, -0.33546578,
#         0.29494853,  0.35686026,  1.16517429,  2.07968374,  0.01780665,
#        -0.21151953,  0.24436976,  0.80695062,  0.97957722,  0.07354918])

# %% [markdown]
# ### Measure of Central Tendency
# #### Mean
# #### Median
# #### Mode

# %%
_mean = np.mean(x)
print(f"Mean of x: {_mean}")
# Out:
# Mean of x: 0.03452787728285098

# %%
plt.hist(x,bins =20, color = 'blue')
plt.axvline(x = _mean, color = 'yellow')

# %%
_median = np.median(x)
print(f"Median of x: {_median}")
# Out:
# Median of x: 0.06206398323991088

# %%
plt.hist(x, bins = 20, color = 'blue')
plt.axvline(x = _mean, color = 'yellow')
plt.axvline(x = _median, color = 'red')
